# %% [markdown]
# # Lab 4: Triangulation
# You will find the complete lab manual in this file. Some exercises require written answers, while others require coding.
#
# **Important:** Do **not** define functions directly in this notebook. Instead, save them in the `functions.py` file and call them from the code cells in this notebook.
#
# ### Submission Requirements:
# Your final lab submission should include:
# 1. Your edited **notebook file** (`.ipynb`).
# 2. Your **`functions.py`** file containing all function definitions.
# 3. A **HTML printout** of the executed notebook with all outputs visible: File → Save and export Notebook As → HTML
#
# First, we'll import a set of python packages you'll need for this lab.

# %%
# for creating responsive plots
# %matplotlib widget  

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import scipy
import matplotlib.image as mpimg

# %% [markdown]
# ## Task 1: Triangulation using Ransac
# This whole lab is basically concerned with the camera equation
# $$ \lambda u = PU $$
# For the uncalibrated case, $u$ is a 3-vector with the homogeneous coordinates of a point in the image
# $$ u = \begin{bmatrix}
# x \\
# y \\
# 1
# \end{bmatrix}  $$
# and $U$ is a 4-vector containing the homogeneous coordinates of the corresponding 3D point.
# The function `triangulation_test_case` is provided for creating a simple test case where you know the correct answer (`U_true`). Gaussian noise of standard deviation `sigma` is added to the image points. Use this example to verify your implemented functions in this lab.

# %%
from supplied import triangulation_test_case

sigma = 0.2
Ps, us, U_true = triangulation_test_case(sigma)
print(f"\nU_true:\n {U_true}")
# Out:
# U_true:
#  [[0.37454012]
#  [0.95071431]
#  [0.73199394]]

# %% [markdown]
# ### Task 1.1:
# Make a minimal solver for the triangulation problem, that is, a function `minimal_triangulation` that takes two camera matrices, `Ps`, and two image points, `us`, and triangulates a 3D point. The image points are in a 2 x n, where n = the number of points, numpy array whereas the camera matrices are in a list containing two numpy arrays. Place the function in your `functions.py` file.

# %%
def minimal_triangulation(Ps, us):
    """
    Ps: list of two (3x4) camera projection matrices as numpy arrays
    us: (2xn) numpy array of image coordinates, where each column corresponds to a point in one image
    Returns: 3D point (3,) as a numpy array
    """

    # Your code here

    return U

# %%
from functions import minimal_triangulation

U = minimal_triangulation(Ps, us)
print(f"\nU:\n {U}")
# Out:
# U:
#  [0.37404098 0.95064611 0.73447876]

# %% [markdown]
# ### Task 1.2:
# Recall that $\lambda$ is the *depth*. Points with negative depth would lie behind the camera, so negative depths indicate that something is wrong. Make a function `check_depths` that takes $N$ camera matrices, `Ps`, and a 3D point, `U`, and checks the depth of `U` in each of the cameras. The output should be a an array of boolean values of length $N$ that indicates which depths were positive. Place it in your `functions.py` file.

# %%
def check_depths(Ps, U):
    """
    Ps: list of camera matrices (each 3x4)
    U: 3D point as a NumPy array of shape (3,)
    
    Returns: NumPy array of 0s and 1s indicating positive depth for each camera
    """

    # Your code here

    return positive

# %%
from functions import check_depths

positive = check_depths(Ps, U)
positive
# Out:
# array([ True,  True])

# %% [markdown]
# ### Task 1.3:
# Make a function `reprojection_errors` that takes $N$ camera matrices, `Ps`, $N$ image points, `us`, and a 3D point, `U`, and computes a vector with the reprojection errors, that is, the lengths of the reprojection residuals. If a point has negative depth, set the reprojection error to `np.inf`. Place it in your `functions.py` file.

# %%
def reprojection_errors(Ps, us, U):
    """
    Ps: list of camera matrices (each 3x4 numpy array)
    us: 2xN numpy array of image coordinates (each column is a point)
    U: 3D point as a numpy array of shape (3,)
    
    Returns: Numpy array of reprojection errors (N,)
    """

    # Your code here

    return errors

# %%
from functions import reprojection_errors

errors = reprojection_errors(Ps, us, U)
errors
# Out:
# array([0.10971567, 0.12055701])

# %% [markdown]
# ### Task 1.4:
# Make a function `ransac_triangulation` that implements triangulation using RANSAC. Use the number of outliers as loss function. A measurement is deemed as an outlier if the depth is negative or if the reprojection error is larger than `threshold`. Place it in your `functions.py` file.

# %%
def ransac_triangulation(Ps, us, threshold):
    """
    Ps: list of camera matrices (each 3x4)
    us: 2xN numpy array of image coordinates
    threshold: reprojection error threshold for inlier selection
    
    Returns:
    - U: best estimated 3D point (3,)
    - nbr_inliers: number of inliers for best estimate
    """

    # Your code here

    return best_U, nbr_inliers

# %%
from functions import ransac_triangulation

threshold =  2
[U, nbr_inliers] = ransac_triangulation(Ps, us, threshold) 

print(f"U:\n {U}")
print(f"\nNumber inliers: {nbr_inliers}")
# Out:
# U:
#  [0.37404098 0.95064611 0.73447876]
#
# Number inliers: 2

# %% [markdown]
# ### Task 1.5:
# In `sequence.mat` you find an array `triangulation_examples` with triangulation examples. Each example (3D point) has a list of camera matrices `Ps` and a 2 x N-array `us` with image points. Run ransac_triangulation for all (or at least 5000) of the examples. Store all triangulated points with at least two inliers and plot them using `scatter`. There will always be a few outliers among the estimated 3D points that make it harder to view the plot. You can use the provided function `clean_for_plot` to clean it up a bit.

# %%
from supplied import clean_for_plot, equal_aspect_ratio

# Load data
data = scipy.io.loadmat('data/sequence.mat')

n_examples = 5000
points3D = data['triangulation_examples'][0][:n_examples]

threshold = 5
Us = np.zeros((3, n_examples))

for i in range(n_examples):
    example = points3D[i]
    Ps = [example['Ps'][0, j] for j in range(example['Ps'].shape[1])]
    xs = example['xs']

    # Your code here
    [U, nbr_inliers] = ransac_triangulation(Ps, xs, threshold)
    if nbr_inliers >= 2:
        Us[:, i] = U

# Plot triangulated points
Uc, removed_indices = clean_for_plot(Us) 

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(Uc[0, :], Uc[1, :], Uc[2, :], marker='.')

# Set axis equal for better scaling
equal_aspect_ratio(ax)
plt.show()

# %% [markdown]
# ## Task 2: Least squares triangulation
# In this part of the lab you will solve the triangulation problem through least squares. Just as in the case of registration, the following pipeline is recommended:
# - Use RANSAC to obtain a rough estimate of the parameters ($U$).
# - Remove all measurements which are outliers with respect to these parameters.
# - Estimate the least squares parameters using the remaining measurements.
#
# Note that in this case a *measurement* is a pair consisting of an image point $u_i$ and a camera matrix $P_i$. Don’t forget that points with negative depths should be outliers.

# %% [markdown]
# ### Task 2.1:
# Consider a camera matrix
# $$ P_i = \begin{bmatrix}
# \leftarrow a_i^T \rightarrow \\
# \leftarrow b_i^T \rightarrow \\
# \leftarrow c_i^T \rightarrow
# \end{bmatrix} , $$
# a 3D point $U$ and an image point $u_i$. Write the exact formula for the reprojection error $r_i(U)$ below.

# %% [markdown]
# **Your answer here:** $$
# r_i(U) = u_i -
# \begin{pmatrix}
# \dfrac{a^T_i\,U}{c^T_i\,U} \\[1em]
# \dfrac{b^T_i\,U}{c^T_i\,U}
# \end{pmatrix}
# $$

# %% [markdown]
# As you can see, the residuals are no longer linear, so computing a least squares solution will be significantly harder than in the previous lab. In fact, we cannot be sure to find the least squares solution. What we can do is to use local optimization to reduce the sum of squared residuals. We start at the solution produced by Ransac and use a few Gauss-Newton iterations.
#
# ### Task 2.2:
# Make a function `compute_residuals` that takes an array `Ps` with $N$ cameras, a 2 x $N$ array `us` of image points and a 3 x 1 array `U`, and computes a 2$N$ x 1 array with all the reprojection residuals stacked into a single vector/array. A reprojection residual is a 2D vector corresponding to the difference between the original measurement and the projected point. The stacked vector is the $\bar{r}$ from the lecture notes (page 99). Place it in your `functions.py` file.

# %%
def compute_residuals(Ps, us, U):
    """
    Ps: list of camera matrices (each 3x4 numpy array)
    us: 2xN numpy array of observed image coordinates
    U: 3D point as a numpy array of shape (3,)
    
    Returns:
    - all_residuals: (2N,) numpy array of residuals (x and y reprojection errors)
    """

    # Your code here

    return all_residuals

# %%
from functions import compute_residuals

# Usage example for one 3D point
index_point = 0
example = points3D[index_point]
Ps_example = [example['Ps'][0, j] for j in range(example['Ps'].shape[1])]
xs_example = example['xs']
U_example =  Us[:,index_point]

all_residuals = compute_residuals(Ps_example, xs_example, U_example)
all_residuals
# Out:
# array([ 10.82941287,   0.60982319,   3.71990062,  -0.23715326,
#          1.47019204,   1.46345624,  -1.62482557,  -3.07950014,
#         -0.15358831,  -1.62858873,  -3.71366076,   0.47712726,
#          8.60055158, -21.79688534,  -0.68084934,  23.73995461,
#         10.82941287,   0.60982319,   3.71990062,  -0.23715326,
#          1.47019204,   1.46345624,  -1.62482557,  -3.07950014,
#         -0.15358831,  -1.62858873,  -3.71366076,   0.47712726,
#          8.60055158, -21.79688534,  -0.68084934,  23.73995461])

# %% [markdown]
# ### Task 2.3:
# Find formulas for the partial derivatives in the Jacobian of $\bar{r}$. The Jacobian should be a 2$N$ x 3- matrix. (Hint: you can start by finding the formula to the Jacobian of the i-th residual, which is a 2x3 matrix.) Please write down the exact formula and give a brief description about each variable that appears in the formula.

# %% [markdown]
# **Your answer here:** $$
# \frac{\partial r_i(U)}{\partial U} =
# -\frac{1}{C^2}
# \begin{bmatrix}
# C\, a_{i1} - A\, c_{i1} & C\, a_{i2} - A\, c_{i2} & C\, a_{i3} - A\, c_{i3} \\
# C\, b_{i1} - B\, c_{i1} & C\, b_{i2} - B\, c_{i2} & C\, b_{i3} - B\, c_{i3}
# \end{bmatrix}
# $$
#
# And $$ A = a_i^T U, B = b_i^T U, C = c_i^T U $$

# %% [markdown]
# ### Task 2.4:
# Make a function `compute_jacobian`, that computes the Jacobian given a 3 x 1- vector `U` and a cell array of camera matrices `Ps`. Place it in your `functions.py` file.

# %%
def compute_jacobian(Ps, U):
    """
    Ps: list of camera matrices (each 3x4 numpy array)
    U: 3D point as a numpy array of shape (3,)
    
    Returns:
    - jacobian: (2N x 3) numpy array, Jacobian matrix of reprojection errors w.r.t. U
    """

    # Your code here

    return jacobian

# Usage example
# all_residuals = compute_jacobian(Ps_example, U_example)

# %%
from functions import compute_jacobian

# Usage example
all_residuals = compute_jacobian(Ps_example, U_example)

# %% [markdown]
# ### Task 2.5:
# Use the functions `compute_residuals` och `compute_jacobian` to make a function `refine_triangulation` that uses an approximate 3D point `Uhat` as a starting point for Gauss-Newton’s method. Use five GaussNewton iterations. Print the sum of squared residuals after each Gauss-Newton step to verify that it decreases. Place it in your `functions.py` file.

# %%
def refine_triangulation(Ps, us, Uhat, iterations=5):
    """
    Refines a 3D point estimate using Gauss-Newton optimization.

    Parameters:
    - Ps: list of camera matrices (3x4 numpy arrays)
    - us: 2xN numpy array of 2D image points
    - Uhat: initial estimate of the 3D point (3,)
    - iterations: number of Gauss-Newton iterations (default: 5)

    Returns:
    - U: refined 3D point (3,)
    """

    # Your code here
    
    return U_temp

# %%
from functions import refine_triangulation

# Usage example
Uref = refine_triangulation(Ps_example, xs_example, U_example)
Uref
# Out:
# The sum of squared residuals: 2114.5297234685327
# The sum of squared residuals: 2114.529723468579
# The sum of squared residuals: 2114.5297234685327
# The sum of squared residuals: 2114.5297234685468
# The sum of squared residuals: 2114.5297234685477
# array([-17.41310784,   3.82017515,   6.78419959])

# %% [markdown]
# ### Task 2.6:
# Try your refine_triangulation on the data in `gauss_newton.mat`. First we will plot the points given in Uhat, then refine each point using your function and plot the results using `scatter3`. You should see an improvement.

# %%
# Load data
data = scipy.io.loadmat('data/gauss_newton.mat')
Uhat = data['Uhat']        # 3xN
u = data['u']              # 2xN
u_tilde = data['u_tilde']  # 2xN
P = data['P']              # 3x4
P_tilde = data['P_tilde']  # 3x4

# Plot initial points
fig = plt.figure(figsize=(10, 5))
ax1 = fig.add_subplot(121, projection='3d')
ax1.scatter(Uhat[0], Uhat[1], Uhat[2], c='blue', marker='.')
ax1.set_title('Initial 3D Points (Uhat)')
ax1.view_init(elev=0, azim=-90)
equal_aspect_ratio(ax1)

# Refine each point
N = Uhat.shape[1]
Uref = np.zeros((3, N))
Ps = [P, P_tilde]

for i in range(N):
    image_points = np.column_stack((u[:, i], u_tilde[:, i]))  # 2x2
    Uref[:, i] = refine_triangulation(Ps, image_points, Uhat[:, i])
# Out:
# The sum of squared residuals: 1343.163997080256
# The sum of squared residuals: 0.04843591027436037
# The sum of squared residuals: 0.008698064485503663
# The sum of squared residuals: 0.008698062486746436
# The sum of squared residuals: 0.0086980624867456
# The sum of squared residuals: 1220.097020087587
# The sum of squared residuals: 0.28059725005684044
# The sum of squared residuals: 0.031988283255307635
# The sum of squared residuals: 0.03198821371946768
# The sum of squared residuals: 0.031988213719464934
# The sum of squared residuals: 1518.8226983101122
# The sum of squared residuals: 0.010070252376560923
# The sum of squared residuals: 0.010042904157557375
# The sum of squared residuals: 0.010042904156216812
# The sum of squared residuals: 0.010042904156217215
# The sum of squared residuals: 671.5403798998223
# The sum of squared residuals: 0.6004681369900171
# The sum of squared residuals: 0.0316400274942552
# The sum of squared residuals: 0.03163946175942302
# The sum of squared residuals: 0.031639461759425086
# The sum of squared residuals: 1377.794813442265
# The sum of squared residuals: 0.21495695880749
# The sum of squared residuals: 0.0025035959974649934
# The sum of squared residuals: 0.0025035628564681273
# The sum of squared residuals: 0.0025035628564676502
# The sum of squared residuals: 1725.3581730252888
# The sum of squared residuals: 0.029864763995260224
# The sum of squared residuals: 0.020693784150395484
# The sum of squared residuals: 0.020693784119814353
# The sum of squared residuals: 0.020693784119814703
# The sum of squared residuals: 1334.3238816944602
# The sum of squared residuals: 0.0336452597039016
# The sum of squared residuals: 0.0012877275935830094
# The sum of squared residuals: 0.0012877268023884505
# The sum of squared residuals: 0.0012877268023883733
# The sum of squared residuals: 1652.100997772467
# The sum of squared residuals: 0.3151665989663357
# The sum of squared residuals: 0.04123080611645359
# The sum of squared residuals: 0.04123077373481
# The sum of squared residuals: 0.04123077373481329
# The sum of squared residuals: 1980.4217514906327
# The sum of squared residuals: 0.15832715899833213
# The sum of squared residuals: 0.0027127020008752916
# The sum of squared residuals: 0.00271266229560454
# The sum of squared residuals: 0.0027126622956045966
# The sum of squared residuals: 866.18420374332
# The sum of squared residuals: 0.16036516382215166
# The sum of squared residuals: 0.12707211079805897
# The sum of squared residuals: 0.12707211052779477
# The sum of squared residuals: 0.12707211052779316
# The sum of squared residuals: 1035.2812424915355
# The sum of squared residuals: 0.28532163667239224
# The sum of squared residuals: 0.1161464874315192
# The sum of squared residuals: 0.11614646462241185
# The sum of squared residuals: 0.11614646462240602
# The sum of squared residuals: 1760.1743647877008
# The sum of squared residuals: 0.37846413118956435
# The sum of squared residuals: 0.002442597381418454
# The sum of squared residuals: 0.0024423982888391585
# The sum of squared residuals: 0.002442398288838934
# The sum of squared residuals: 1422.7235794743215
# The sum of squared residuals: 0.1460736589964796
# The sum of squared residuals: 0.0038550227913624864
# The sum of squared residuals: 0.0038550090014474033
# The sum of squared residuals: 0.003855009001446517
# The sum of squared residuals: 930.1334717975355
# The sum of squared residuals: 0.05751253348650859
# The sum of squared residuals: 0.0270491595217442
# The sum of squared residuals: 0.027049159405882716
# The sum of squared residuals: 0.027049159405886005
# The sum of squared residuals: 991.1116157752724
# The sum of squared residuals: 0.12139896591915726
# The sum of squared residuals: 0.01808494950593697
# The sum of squared residuals: 0.018084947881126634
# The sum of squared residuals: 0.01808494788112453
# The sum of squared residuals: 1034.6223519303603
# The sum of squared residuals: 0.28528215940372376
# The sum of squared residuals: 0.004825229280150904
# The sum of squared residuals: 0.004825208471719754
# The sum of squared residuals: 0.004825208471719664
# The sum of squared residuals: 1607.2573873405763
# The sum of squared residuals: 0.09370697578199073
# The sum of squared residuals: 0.029458582518321726
# The sum of squared residuals: 0.029458541480155573
# The sum of squared residuals: 0.029458541480158328
# The sum of squared residuals: 1049.5733188310383
# The sum of squared residuals: 0.18308735046154195
# The sum of squared residuals: 0.00027061801944078923
# The sum of squared residuals: 0.0002705972616283116
# The sum of squared residuals: 0.0002705972616285139
# The sum of squared residuals: 1113.2151096821042
# The sum of squared residuals: 0.20434371688268746
# The sum of squared residuals: 0.1975443669962679
# The sum of squared residuals: 0.1975443669884241
# The sum of squared residuals: 0.19754436698842495
# The sum of squared residuals: 1875.4618114618963
# The sum of squared residuals: 0.18404954912115473
# The sum of squared residuals: 0.10300111684261973
# The sum of squared residuals: 0.10300111623786384
# The sum of squared residuals: 0.10300111623786513
# The sum of squared residuals: 438.5669802682995
# The sum of squared residuals: 0.059089653317872
# The sum of squared residuals: 0.00802466581905676
# The sum of squared residuals: 0.008024665233609202
# The sum of squared residuals: 0.00802466523360888
# The sum of squared residuals: 1096.496258670068
# The sum of squared residuals: 0.26341754508271753
# The sum of squared residuals: 0.06669859032318862
# The sum of squared residuals: 0.06669855891817707
# The sum of squared residuals: 0.0666985589181818
# The sum of squared residuals: 455.57037570305994
# The sum of squared residuals: 0.2694598373908882
# The sum of squared residuals: 0.12405348289629282
# The sum of squared residuals: 0.12405345949801545
# The sum of squared residuals: 0.1240534594980181
# The sum of squared residuals: 1304.8927925069386
# The sum of squared residuals: 0.18261840541205288
# The sum of squared residuals: 0.015321984888706973
# The sum of squared residuals: 0.015321979846344803
# The sum of squared residuals: 0.015321979846345025
# The sum of squared residuals: 158.10736095879597
# The sum of squared residuals: 0.0007443140936245999
# The sum of squared residuals: 0.000712619876713054
# The sum of squared residuals: 0.0007126198765711845
# The sum of squared residuals: 0.0007126198765711661
# The sum of squared residuals: 781.8250844603632
# The sum of squared residuals: 0.4528428383964786
# The sum of squared residuals: 0.20733059757247174
# The sum of squared residuals: 0.20733056561968233
# The sum of squared residuals: 0.2073305656196873
# The sum of squared residuals: 1329.3854660263537
# The sum of squared residuals: 0.6264155250523681
# The sum of squared residuals: 0.04248583624434987
# The sum of squared residuals: 0.042485743280137475
# The sum of squared residuals: 0.04248574328013721
# The sum of squared residuals: 992.6901828673114
# The sum of squared residuals: 0.0959526583666061
# The sum of squared residuals: 0.05992030109891182
# The sum of squared residuals: 0.05992030107931598
# The sum of squared residuals: 0.0599203010793157
# The sum of squared residuals: 653.7251866141194
# The sum of squared residuals: 0.09333917079256696
# The sum of squared residuals: 0.034190321560438344
# The sum of squared residuals: 0.034190321028211616
# The sum of squared residuals: 0.034190321028214926
# The sum of squared residuals: 974.8610349610673
# The sum of squared residuals: 0.0775261585978719
# The sum of squared residuals: 0.06729642181226378
# The sum of squared residuals: 0.06729642169590735
# The sum of squared residuals: 0.06729642169590443
# The sum of squared residuals: 866.599507571965
# The sum of squared residuals: 0.20863702224957356
# The sum of squared residuals: 0.20527150839726369
# The sum of squared residuals: 0.20527150832815924
# The sum of squared residuals: 0.20527150832816204
# The sum of squared residuals: 225.34531617611478
# The sum of squared residuals: 0.4004988954976106
# The sum of squared residuals: 0.38304976888343395
# The sum of squared residuals: 0.3830497686660574
# The sum of squared residuals: 0.38304976866606
# The sum of squared residuals: 398.35751986366006
# The sum of squared residuals: 0.05650624597384944
# The sum of squared residuals: 0.05650447017136711
# The sum of squared residuals: 0.056504470171368316
# The sum of squared residuals: 0.05650447017136619
# The sum of squared residuals: 87.09010622412717
# The sum of squared residuals: 0.021867968370009094
# The sum of squared residuals: 0.018710959181560363
# The sum of squared residuals: 0.018710959175966206
# The sum of squared residuals: 0.018710959175965866
# The sum of squared residuals: 772.3587729068954
# The sum of squared residuals: 0.022887375049007203
# The sum of squared residuals: 0.022052038592811584
# The sum of squared residuals: 0.022052038586278112
# The sum of squared residuals: 0.022052038586277065
# The sum of squared residuals: 505.2477905351898
# The sum of squared residuals: 0.02664860303799445
# The sum of squared residuals: 0.02311999406149877
# The sum of squared residuals: 0.02311999406044634
# The sum of squared residuals: 0.023119994060446902
# The sum of squared residuals: 724.4983810481901
# The sum of squared residuals: 0.01267757072984656
# The sum of squared residuals: 0.012672521998617844
# The sum of squared residuals: 0.012672521998562671
# The sum of squared residuals: 0.012672521998561843
# The sum of squared residuals: 576.6824049777193
# The sum of squared residuals: 0.1536661161416515
# The sum of squared residuals: 0.07640978575958907
# The sum of squared residuals: 0.07640978348290703
# The sum of squared residuals: 0.07640978348291048
# The sum of squared residuals: 1053.3248149091937
# The sum of squared residuals: 0.3048819124962395
# The sum of squared residuals: 0.05170312987305629
# The sum of squared residuals: 0.05170311410111643
# The sum of squared residuals: 0.0517031141011141
# The sum of squared residuals: 813.9723752890142
# The sum of squared residuals: 0.03521749858501287
# The sum of squared residuals: 0.016319391192294967
# The sum of squared residuals: 0.016319391188745872
# The sum of squared residuals: 0.01631939118874544
# The sum of squared residuals: 482.05285807837555
# The sum of squared residuals: 0.045892086406762816
# The sum of squared residuals: 0.029994343826703917
# The sum of squared residuals: 0.02999434378119316
# The sum of squared residuals: 0.02999434378119168
# The sum of squared residuals: 743.3103009287266
# The sum of squared residuals: 0.07934801705053841
# The sum of squared residuals: 0.032137512984165964
# The sum of squared residuals: 0.03213751278834617
# The sum of squared residuals: 0.03213751278834531
# The sum of squared residuals: 1130.9041426408216
# The sum of squared residuals: 0.0617822815566778
# The sum of squared residuals: 0.018509955329399155
# The sum of squared residuals: 0.018509955293399643
# The sum of squared residuals: 0.018509955293402082
# The sum of squared residuals: 195.49025878148288
# The sum of squared residuals: 0.13468572749817212
# The sum of squared residuals: 1.3064251760687875e-06
# The sum of squared residuals: 1.2490769526534383e-06
# The sum of squared residuals: 1.2490769526621312e-06
# The sum of squared residuals: 538.1759810027644
# The sum of squared residuals: 0.0733560527514365
# The sum of squared residuals: 0.013572894156735738
# The sum of squared residuals: 0.01357289286902649
# The sum of squared residuals: 0.013572892869027008
# The sum of squared residuals: 480.9235259446777
# The sum of squared residuals: 0.1021786881836888
# The sum of squared residuals: 0.0025344871458553146
# The sum of squared residuals: 0.0025344804621233582
# The sum of squared residuals: 0.002534480462123205
# The sum of squared residuals: 393.82112595730763
# The sum of squared residuals: 0.2326742277610376
# The sum of squared residuals: 0.005909327215892349
# The sum of squared residuals: 0.0059092406767373646
# The sum of squared residuals: 0.005909240676737919
# The sum of squared residuals: 1222.64815034631
# The sum of squared residuals: 0.1823943367942775
# The sum of squared residuals: 4.9249326532750683e-05
# The sum of squared residuals: 4.924574922268126e-05
# The sum of squared residuals: 4.924574922269958e-05
# The sum of squared residuals: 451.724200733478
# The sum of squared residuals: 0.23616839037117496
# The sum of squared residuals: 0.036988350669288635
# The sum of squared residuals: 0.03698829624100887
# The sum of squared residuals: 0.036988296241006816
# The sum of squared residuals: 708.8623009047413
# The sum of squared residuals: 0.021259791978253638
# The sum of squared residuals: 0.016137380736089876
# The sum of squared residuals: 0.016137380730133724
# The sum of squared residuals: 0.016137380730132683
# The sum of squared residuals: 1077.812292447574
# The sum of squared residuals: 0.2269465080360644
# The sum of squared residuals: 0.03238993856206747
# The sum of squared residuals: 0.032389933315986635
# The sum of squared residuals: 0.03238993331598511
# The sum of squared residuals: 745.9716854935782
# The sum of squared residuals: 0.006961634280083968
# The sum of squared residuals: 0.006961291897660945
# The sum of squared residuals: 0.006961291897660362
# The sum of squared residuals: 0.006961291897659767
# The sum of squared residuals: 1150.3192934347471
# The sum of squared residuals: 0.11502373626511264
# The sum of squared residuals: 0.05460543078151942
# The sum of squared residuals: 0.05460542845376344
# The sum of squared residuals: 0.054605428453758875
# The sum of squared residuals: 708.2051871999896
# The sum of squared residuals: 0.04190942263340683
# The sum of squared residuals: 0.014987194310515397
# The sum of squared residuals: 0.014987194188208954
# The sum of squared residuals: 0.01498719418821182
# The sum of squared residuals: 1522.0656645568433
# The sum of squared residuals: 0.05078762181258498
# The sum of squared residuals: 0.029271065618049305
# The sum of squared residuals: 0.02927106561439809
# The sum of squared residuals: 0.029271065614398246
# The sum of squared residuals: 769.9501272711699
# The sum of squared residuals: 0.12047322748350575
# The sum of squared residuals: 0.06193218690131438
# The sum of squared residuals: 0.06193218679126123
# The sum of squared residuals: 0.06193218679126061
# The sum of squared residuals: 899.7299337077031
# The sum of squared residuals: 0.16564388053144274
# The sum of squared residuals: 0.020615524489090688
# The sum of squared residuals: 0.020615500450281023
# The sum of squared residuals: 0.02061550045028141
# The sum of squared residuals: 767.4599858389265
# The sum of squared residuals: 0.2769530269634699
# The sum of squared residuals: 0.04539876368943149
# The sum of squared residuals: 0.045398730658170475
# The sum of squared residuals: 0.04539873065817012
# The sum of squared residuals: 1064.4632866765546
# The sum of squared residuals: 0.17893519520756826
# The sum of squared residuals: 0.10275331962008435
# The sum of squared residuals: 0.10275331955810935
# The sum of squared residuals: 0.10275331955810904
# The sum of squared residuals: 1016.7656700798929
# The sum of squared residuals: 0.34105851258163083
# The sum of squared residuals: 0.006078421154248486
# The sum of squared residuals: 0.00607838532546769
# The sum of squared residuals: 0.006078385325467818
# The sum of squared residuals: 521.1870835307219
# The sum of squared residuals: 0.12398258538374013
# The sum of squared residuals: 0.09058827648825632
# The sum of squared residuals: 0.09058827641916842
# The sum of squared residuals: 0.09058827641917383
# The sum of squared residuals: 683.7246242589139
# The sum of squared residuals: 0.16425960716008536
# The sum of squared residuals: 0.08574774781834675
# The sum of squared residuals: 0.0857477471279369
# The sum of squared residuals: 0.0857477471279377
# The sum of squared residuals: 820.1124718734924
# The sum of squared residuals: 0.1366003760015353
# The sum of squared residuals: 0.11741319618719492
# The sum of squared residuals: 0.11741319615537274
# The sum of squared residuals: 0.11741319615537282
# The sum of squared residuals: 639.8128962295816
# The sum of squared residuals: 0.039665357322793054
# The sum of squared residuals: 0.022019960817851035
# The sum of squared residuals: 0.022019960804033623
# The sum of squared residuals: 0.02201996080403515
# The sum of squared residuals: 783.1981404868941
# The sum of squared residuals: 0.4062056328286318
# The sum of squared residuals: 0.00025156996869877553
# The sum of squared residuals: 0.0002514762823328443
# The sum of squared residuals: 0.00025147628233313977
# The sum of squared residuals: 767.8814696843949
# The sum of squared residuals: 0.07881297341298457
# The sum of squared residuals: 0.008764338835591122
# The sum of squared residuals: 0.00876433838319155
# The sum of squared residuals: 0.00876433838319345
# The sum of squared residuals: 1003.2291417514947
# The sum of squared residuals: 0.341208335063604
# The sum of squared residuals: 0.00498015933086041
# The sum of squared residuals: 0.00498011757628793
# The sum of squared residuals: 0.004980117576288192
# The sum of squared residuals: 1341.1292193011918
# The sum of squared residuals: 0.06613386178585934
# The sum of squared residuals: 0.06468077113856074
# The sum of squared residuals: 0.06468077113672152
# The sum of squared residuals: 0.06468077113672231
# The sum of squared residuals: 1521.3544010356811
# The sum of squared residuals: 0.03056479143064533
# The sum of squared residuals: 0.009792834041087377
# The sum of squared residuals: 0.009792834019009182
# The sum of squared residuals: 0.009792834019010715
# The sum of squared residuals: 1527.3396838107685
# The sum of squared residuals: 0.13406228288144711
# The sum of squared residuals: 0.0038508948161207835
# The sum of squared residuals: 0.003850894598498299
# The sum of squared residuals: 0.003850894598498171
# The sum of squared residuals: 1094.5030086686395
# The sum of squared residuals: 0.34848624721968763
# The sum of squared residuals: 0.0038423350945543575
# The sum of squared residuals: 0.0038422858793842997
# The sum of squared residuals: 0.0038422858793845044
# The sum of squared residuals: 939.9232280963497
# The sum of squared residuals: 0.019369327489333062
# The sum of squared residuals: 0.00044623279876132636
# The sum of squared residuals: 0.00044623250608700766
# The sum of squared residuals: 0.00044623250608691095
# The sum of squared residuals: 1291.604906799637
# The sum of squared residuals: 0.18151885398693526
# The sum of squared residuals: 0.006270983728127383
# The sum of squared residuals: 0.006270980844174686
# The sum of squared residuals: 0.006270980844174624
# The sum of squared residuals: 1884.8833774587272
# The sum of squared residuals: 0.08871596629541169
# The sum of squared residuals: 0.002384815317151668
# The sum of squared residuals: 0.002384814183349698
# The sum of squared residuals: 0.002384814183349595
# The sum of squared residuals: 2076.4395970018145
# The sum of squared residuals: 0.025534483127048584
# The sum of squared residuals: 0.00770587669440702
# The sum of squared residuals: 0.007705876689473317
# The sum of squared residuals: 0.007705876689472993
# The sum of squared residuals: 1602.696372507724
# The sum of squared residuals: 0.05405766307749417
# The sum of squared residuals: 0.051370579572041844
# The sum of squared residuals: 0.05137057955860348
# The sum of squared residuals: 0.05137057955860322
# The sum of squared residuals: 1761.8232185542834
# The sum of squared residuals: 0.6551667324388808
# The sum of squared residuals: 0.021597208470179614
# The sum of squared residuals: 0.02159702774416544
# The sum of squared residuals: 0.02159702774416572
# The sum of squared residuals: 622.8548631188555
# The sum of squared residuals: 0.10787424762634926
# The sum of squared residuals: 0.07765168754713159
# The sum of squared residuals: 0.0776516875296378
# The sum of squared residuals: 0.07765168752963572
# The sum of squared residuals: 1305.570308474386
# The sum of squared residuals: 0.17137725056632397
# The sum of squared residuals: 0.006884730306800041
# The sum of squared residuals: 0.0068847290839388325
# The sum of squared residuals: 0.006884729083938669
# The sum of squared residuals: 1386.5800101482266
# The sum of squared residuals: 0.5188682739715598
# The sum of squared residuals: 0.03461174079194134
# The sum of squared residuals: 0.034611684205964215
# The sum of squared residuals: 0.034611684205963764
# The sum of squared residuals: 1590.9945244694284
# The sum of squared residuals: 0.06934382635482468
# The sum of squared residuals: 0.0014851830377421427
# The sum of squared residuals: 0.0014851827642785953
# The sum of squared residuals: 0.0014851827642779292
# The sum of squared residuals: 920.5864293637698
# The sum of squared residuals: 0.09015719373140936
# The sum of squared residuals: 0.0887471327092364
# The sum of squared residuals: 0.08874713270760554
# The sum of squared residuals: 0.08874713270760665
# The sum of squared residuals: 675.3138379351996
# The sum of squared residuals: 0.17867026592981355
# The sum of squared residuals: 2.842118351585176e-08
# The sum of squared residuals: 1.1862384448856965e-08
# The sum of squared residuals: 1.186238444880797e-08
# The sum of squared residuals: 1276.3669127760254
# The sum of squared residuals: 0.06633239602081407
# The sum of squared residuals: 0.00047918215293202976
# The sum of squared residuals: 0.00047918121252145624
# The sum of squared residuals: 0.0004791812125218713
# The sum of squared residuals: 2350.535284979478
# The sum of squared residuals: 0.13966945884486123
# The sum of squared residuals: 0.028931056781255394
# The sum of squared residuals: 0.028931056578307066
# The sum of squared residuals: 0.028931056578308204
# The sum of squared residuals: 1203.3071411661667
# The sum of squared residuals: 0.083789678239566
# The sum of squared residuals: 0.02001714689652866
# The sum of squared residuals: 0.020017146775583423
# The sum of squared residuals: 0.020017146775581807
# The sum of squared residuals: 1311.2929691265172
# The sum of squared residuals: 0.05507514678723378
# The sum of squared residuals: 0.006058572767786597
# The sum of squared residuals: 0.0060585727648193284
# The sum of squared residuals: 0.006058572764818608
# The sum of squared residuals: 1942.6477123808947
# The sum of squared residuals: 0.09346273985147828
# The sum of squared residuals: 0.014392553427960825
# The sum of squared residuals: 0.014392552115927403
# The sum of squared residuals: 0.014392552115929947
# The sum of squared residuals: 1830.7233046140443
# The sum of squared residuals: 0.05997715091984007
# The sum of squared residuals: 0.051507704298284954
# The sum of squared residuals: 0.05150770429552857
# The sum of squared residuals: 0.051507704295528076
# The sum of squared residuals: 1907.84488778837
# The sum of squared residuals: 0.12114301800330773
# The sum of squared residuals: 0.05693525783056701
# The sum of squared residuals: 0.0569352543461842
# The sum of squared residuals: 0.05693525434618331
# The sum of squared residuals: 1654.8072289410372
# The sum of squared residuals: 0.046742563515753746
# The sum of squared residuals: 0.00012054695157976698
# The sum of squared residuals: 0.00012054648800531413
# The sum of squared residuals: 0.00012054648800537715
# The sum of squared residuals: 1525.5981453500365
# The sum of squared residuals: 0.856811782489665
# The sum of squared residuals: 0.03936392614348855
# The sum of squared residuals: 0.03936371972098264
# The sum of squared residuals: 0.03936371972098561
# The sum of squared residuals: 1733.5835188618598
# The sum of squared residuals: 0.10102636873524712
# The sum of squared residuals: 0.026198016971145578
# The sum of squared residuals: 0.026198014648872073
# The sum of squared residuals: 0.026198014648872035
# The sum of squared residuals: 1861.4585371999087
# The sum of squared residuals: 0.5848373081109384
# The sum of squared residuals: 0.0008328451249106843
# The sum of squared residuals: 0.0008327254506247737
# The sum of squared residuals: 0.0008327254506252262
# The sum of squared residuals: 1597.1199311255182
# The sum of squared residuals: 0.34352723376530425
# The sum of squared residuals: 0.021760904349326364
# The sum of squared residuals: 0.021760891199496982
# The sum of squared residuals: 0.021760891199499616
# The sum of squared residuals: 2482.428509524618
# The sum of squared residuals: 0.23901704799176102
# The sum of squared residuals: 0.09121922306862384
# The sum of squared residuals: 0.09121922270585293
# The sum of squared residuals: 0.09121922270585475
# The sum of squared residuals: 1921.583609827907
# The sum of squared residuals: 0.321904690254078
# The sum of squared residuals: 2.3753584193575498e-05
# The sum of squared residuals: 2.3742365063865026e-05
# The sum of squared residuals: 2.374236506390956e-05
# The sum of squared residuals: 1642.1182940479282
# The sum of squared residuals: 0.13289415238357957
# The sum of squared residuals: 0.017741639164292566
# The sum of squared residuals: 0.017741635867801128
# The sum of squared residuals: 0.017741635867803522
# The sum of squared residuals: 2312.47955108702
# The sum of squared residuals: 0.35155486287291243
# The sum of squared residuals: 0.12189702638737832
# The sum of squared residuals: 0.1218970247916021
# The sum of squared residuals: 0.12189702479160089
# The sum of squared residuals: 2523.876180310116
# The sum of squared residuals: 0.17265070260706225
# The sum of squared residuals: 0.07989349681107696
# The sum of squared residuals: 0.07989349621564394
# The sum of squared residuals: 0.07989349621564193
# The sum of squared residuals: 1679.7986158776598
# The sum of squared residuals: 0.5790629886198648
# The sum of squared residuals: 0.014653687193065456
# The sum of squared residuals: 0.014653615732174186
# The sum of squared residuals: 0.014653615732172142
# The sum of squared residuals: 2160.815573878693
# The sum of squared residuals: 0.16522111044456142
# The sum of squared residuals: 0.14958280646635552
# The sum of squared residuals: 0.1495828063028552
# The sum of squared residuals: 0.14958280630285375
# The sum of squared residuals: 1874.2960504180462
# The sum of squared residuals: 0.068852108115165
# The sum of squared residuals: 0.016660840200149196
# The sum of squared residuals: 0.01666083968797697
# The sum of squared residuals: 0.016660839687976284
# The sum of squared residuals: 2622.5571347739838
# The sum of squared residuals: 0.35914408594301783
# The sum of squared residuals: 0.0018356367592552414
# The sum of squared residuals: 0.0018356299346162426
# The sum of squared residuals: 0.0018356299346165906
# The sum of squared residuals: 1412.366654632393
# The sum of squared residuals: 0.09306162308327091
# The sum of squared residuals: 0.034045677589170945
# The sum of squared residuals: 0.03404567712386146
# The sum of squared residuals: 0.034045677123859606
# The sum of squared residuals: 1496.7064639965752
# The sum of squared residuals: 0.1432955630853868
# The sum of squared residuals: 0.05881005455383084
# The sum of squared residuals: 0.05881005450788475
# The sum of squared residuals: 0.05881005450788403
# The sum of squared residuals: 2767.0810650400354
# The sum of squared residuals: 0.26975983946748416
# The sum of squared residuals: 0.011204452123985404
# The sum of squared residuals: 0.011204452103502113
# The sum of squared residuals: 0.011204452103501742
# The sum of squared residuals: 2063.6696030056246
# The sum of squared residuals: 0.21999231666683938
# The sum of squared residuals: 0.0199075568612281
# The sum of squared residuals: 0.01990755216385903
# The sum of squared residuals: 0.019907552163857773
# The sum of squared residuals: 2470.270950505479
# The sum of squared residuals: 0.1731162396942709
# The sum of squared residuals: 0.009293935970415307
# The sum of squared residuals: 0.00929393596054601
# The sum of squared residuals: 0.009293935960544071
# The sum of squared residuals: 2970.425523254338
# The sum of squared residuals: 0.3717554853125101
# The sum of squared residuals: 0.00028435814425148415
# The sum of squared residuals: 0.0002843571965069996
# The sum of squared residuals: 0.0002843571965068869
# The sum of squared residuals: 1924.7126294212237
# The sum of squared residuals: 0.4185887316429973
# The sum of squared residuals: 0.0016501890911759167
# The sum of squared residuals: 0.001650177172713315
# The sum of squared residuals: 0.0016501771727136778
# The sum of squared residuals: 2302.1685732215255
# The sum of squared residuals: 0.2855833736899723
# The sum of squared residuals: 6.231256530583518e-06
# The sum of squared residuals: 6.229207820168109e-06
# The sum of squared residuals: 6.229207820099353e-06
# The sum of squared residuals: 1162.5639121468014
# The sum of squared residuals: 0.27550963065183975
# The sum of squared residuals: 0.052185088439822516
# The sum of squared residuals: 0.05218508347800264
# The sum of squared residuals: 0.05218508347800262
# The sum of squared residuals: 1091.7709142579763
# The sum of squared residuals: 0.11922125660812381
# The sum of squared residuals: 0.08454167547455026
# The sum of squared residuals: 0.08454167543972851
# The sum of squared residuals: 0.08454167543972488
# The sum of squared residuals: 1612.5642885258947
# The sum of squared residuals: 0.014083117267738532
# The sum of squared residuals: 0.001833619212277311
# The sum of squared residuals: 0.0018336192070834323
# The sum of squared residuals: 0.0018336192070838148
# The sum of squared residuals: 2386.429165634667
# The sum of squared residuals: 0.01737599647595613
# The sum of squared residuals: 0.00020449444890792662
# The sum of squared residuals: 0.00020449443466568707
# The sum of squared residuals: 0.0002044944346655431
# The sum of squared residuals: 2784.0374871893564
# The sum of squared residuals: 0.054656120248083695
# The sum of squared residuals: 0.04515619666966918
# The sum of squared residuals: 0.045156196628150916
# The sum of squared residuals: 0.045156196628154635
# The sum of squared residuals: 1479.458254910113
# The sum of squared residuals: 0.20658841308663928
# The sum of squared residuals: 0.2065128199848886
# The sum of squared residuals: 0.20651281998468485
# The sum of squared residuals: 0.206512819984686
# The sum of squared residuals: 1915.7708566801525
# The sum of squared residuals: 0.07286970499539333
# The sum of squared residuals: 0.07141738493753227
# The sum of squared residuals: 0.07141738493694665
# The sum of squared residuals: 0.07141738493694384
# The sum of squared residuals: 1324.10107093714
# The sum of squared residuals: 0.02322077456917758
# The sum of squared residuals: 0.00019536362133703702
# The sum of squared residuals: 0.00019536355491974543
# The sum of squared residuals: 0.00019536355491979107
# The sum of squared residuals: 3189.187077443968
# The sum of squared residuals: 0.07642382000799611
# The sum of squared residuals: 0.0276578628390559
# The sum of squared residuals: 0.027657862811173713
# The sum of squared residuals: 0.02765786281117323
# The sum of squared residuals: 1418.4103276248034
# The sum of squared residuals: 0.14476169783872878
# The sum of squared residuals: 0.08859424417380896
# The sum of squared residuals: 0.0885942441377037
# The sum of squared residuals: 0.08859424413769684
# The sum of squared residuals: 2534.2395440954992
# The sum of squared residuals: 0.048215422753677795
# The sum of squared residuals: 0.014740167303896875
# The sum of squared residuals: 0.014740167176400042
# The sum of squared residuals: 0.01474016717639984
# The sum of squared residuals: 1973.080240426811
# The sum of squared residuals: 0.6353109492433087
# The sum of squared residuals: 0.06877544458006518
# The sum of squared residuals: 0.0687754242401932
# The sum of squared residuals: 0.06877542424019152
# The sum of squared residuals: 2382.6516661460746
# The sum of squared residuals: 0.21924636131747582
# The sum of squared residuals: 0.11119789249274413
# The sum of squared residuals: 0.11119789199483088
# The sum of squared residuals: 0.11119789199483392
# The sum of squared residuals: 1985.9573832026242
# The sum of squared residuals: 0.02190079975902382
# The sum of squared residuals: 0.012033433442867326
# The sum of squared residuals: 0.01203343343571815
# The sum of squared residuals: 0.012033433435715325
# The sum of squared residuals: 1877.1213465202554
# The sum of squared residuals: 0.3062962858726729
# The sum of squared residuals: 0.13620325317584342
# The sum of squared residuals: 0.13620325263992397
# The sum of squared residuals: 0.13620325263992492
# The sum of squared residuals: 1739.1977993292426
# The sum of squared residuals: 0.2285250075525363
# The sum of squared residuals: 0.00010470356352325698
# The sum of squared residuals: 0.00010469154575868205
# The sum of squared residuals: 0.00010469154575870844
# The sum of squared residuals: 1887.0570472303918
# The sum of squared residuals: 0.027965307383152938
# The sum of squared residuals: 0.0006008181727010492
# The sum of squared residuals: 0.0006008173743890131
# The sum of squared residuals: 0.0006008173743892966
# The sum of squared residuals: 2015.604867405259
# The sum of squared residuals: 0.03312629057197725
# The sum of squared residuals: 0.011628691506124163
# The sum of squared residuals: 0.011628691503747388
# The sum of squared residuals: 0.0116286915037473
# The sum of squared residuals: 2621.690754470723
# The sum of squared residuals: 0.0011273537851901462
# The sum of squared residuals: 0.0004819430501524065
# The sum of squared residuals: 0.00048194304775492277
# The sum of squared residuals: 0.00048194304775531194
# The sum of squared residuals: 2330.3998936609805
# The sum of squared residuals: 0.04859019906484513
# The sum of squared residuals: 0.0010356629762017977
# The sum of squared residuals: 0.0010356628957947044
# The sum of squared residuals: 0.0010356628957947083
# The sum of squared residuals: 2137.8664166602657
# The sum of squared residuals: 0.22856530794872726
# The sum of squared residuals: 0.10710798915758775
# The sum of squared residuals: 0.10710798902657348
# The sum of squared residuals: 0.1071079890265747
# The sum of squared residuals: 2688.1143848368743
# The sum of squared residuals: 0.0012886410106987649
# The sum of squared residuals: 0.0006909340775974929
# The sum of squared residuals: 0.0006909340764020807
# The sum of squared residuals: 0.0006909340764020511
# The sum of squared residuals: 2286.130600755353
# The sum of squared residuals: 0.1865009749195762
# The sum of squared residuals: 0.07490033603133885
# The sum of squared residuals: 0.07490033420958105
# The sum of squared residuals: 0.0749003342095809
# The sum of squared residuals: 2373.151718343772
# The sum of squared residuals: 1.9748489197114716
# The sum of squared residuals: 0.3745966190653318
# The sum of squared residuals: 0.3745956256003745
# The sum of squared residuals: 0.3745956256003786
# The sum of squared residuals: 1471.2475039589372
# The sum of squared residuals: 0.22641267678587212
# The sum of squared residuals: 1.298442413518237e-05
# The sum of squared residuals: 1.2980946928727329e-05
# The sum of squared residuals: 1.2980946928716114e-05
# The sum of squared residuals: 3205.4209280958626
# The sum of squared residuals: 0.4382705988653692
# The sum of squared residuals: 0.0055962408946968025
# The sum of squared residuals: 0.005596240112894477
# The sum of squared residuals: 0.005596240112892679
# The sum of squared residuals: 1497.8144771789566
# The sum of squared residuals: 0.014035069588948793
# The sum of squared residuals: 0.010021607637454553
# The sum of squared residuals: 0.010021607637199993
# The sum of squared residuals: 0.010021607637199106
# The sum of squared residuals: 2511.1064657015177
# The sum of squared residuals: 0.41455180548266457
# The sum of squared residuals: 0.036238180407002024
# The sum of squared residuals: 0.03623817905764568
# The sum of squared residuals: 0.03623817905764763
# The sum of squared residuals: 2627.4143733828973
# The sum of squared residuals: 0.12591672146531502
# The sum of squared residuals: 0.05122503204308205
# The sum of squared residuals: 0.051225031924029496
# The sum of squared residuals: 0.05122503192403295
# The sum of squared residuals: 2113.583301018542
# The sum of squared residuals: 0.34249592901990333
# The sum of squared residuals: 0.10118736262912298
# The sum of squared residuals: 0.10118736069409925
# The sum of squared residuals: 0.10118736069410095
# The sum of squared residuals: 1613.7379819208463
# The sum of squared residuals: 0.15538841893485913
# The sum of squared residuals: 0.15388116749698755
# The sum of squared residuals: 0.15388116747455322
# The sum of squared residuals: 0.15388116747455194
# The sum of squared residuals: 2038.5222582116778
# The sum of squared residuals: 0.06613031357829621
# The sum of squared residuals: 0.0037597752646473456
# The sum of squared residuals: 0.0037597659817802083
# The sum of squared residuals: 0.003759765981780379
# The sum of squared residuals: 1346.5980986950674
# The sum of squared residuals: 0.050692210393467454
# The sum of squared residuals: 0.003195262802869481
# The sum of squared residuals: 0.0031952628000924714
# The sum of squared residuals: 0.0031952628000917896
# The sum of squared residuals: 1887.9539761768337
# The sum of squared residuals: 0.09769035816316889
# The sum of squared residuals: 0.015564614528332996
# The sum of squared residuals: 0.015564614476288487
# The sum of squared residuals: 0.015564614476286619
# The sum of squared residuals: 2071.457916651457
# The sum of squared residuals: 0.3338971712949139
# The sum of squared residuals: 0.09281695543785476
# The sum of squared residuals: 0.09281694846100208
# The sum of squared residuals: 0.09281694846099957
# The sum of squared residuals: 1822.8848055507976
# The sum of squared residuals: 1.1588996574709005
# The sum of squared residuals: 0.00690705598159924
# The sum of squared residuals: 0.006906371133006314
# The sum of squared residuals: 0.006906371133007646
# The sum of squared residuals: 2289.9386736386923
# The sum of squared residuals: 0.16375407058918273
# The sum of squared residuals: 0.0008442823312996209
# The sum of squared residuals: 0.0008442728824057852
# The sum of squared residuals: 0.0008442728824056178
# The sum of squared residuals: 1956.6152660328612
# The sum of squared residuals: 0.027620322896390503
# The sum of squared residuals: 0.024875982927986616
# The sum of squared residuals: 0.024875982913221503
# The sum of squared residuals: 0.024875982913221573
# The sum of squared residuals: 2442.1690976589775
# The sum of squared residuals: 1.1848427398430137
# The sum of squared residuals: 0.02555741056048049
# The sum of squared residuals: 0.02555721802776273
# The sum of squared residuals: 0.02555721802776558
# The sum of squared residuals: 1460.7404697388185
# The sum of squared residuals: 1.481476696061928
# The sum of squared residuals: 0.05963539868408196
# The sum of squared residuals: 0.059633565616603774
# The sum of squared residuals: 0.05963356561660413
# The sum of squared residuals: 1891.3591478955325
# The sum of squared residuals: 0.09065873225348317
# The sum of squared residuals: 0.051570964047822285
# The sum of squared residuals: 0.05157096402229212
# The sum of squared residuals: 0.051570964022293386
# The sum of squared residuals: 1505.461378060279
# The sum of squared residuals: 0.07241931537586467
# The sum of squared residuals: 0.04118616537508622
# The sum of squared residuals: 0.041186163932546774
# The sum of squared residuals: 0.04118616393254702
# The sum of squared residuals: 1733.5572199082485
# The sum of squared residuals: 0.16418297386758368
# The sum of squared residuals: 0.011530928729670958
# The sum of squared residuals: 0.011530925936637494
# The sum of squared residuals: 0.011530925936637126
# The sum of squared residuals: 3318.47487352677
# The sum of squared residuals: 0.6164101363232901
# The sum of squared residuals: 0.1814746829523529
# The sum of squared residuals: 0.18147466593837752
# The sum of squared residuals: 0.18147466593837489
# The sum of squared residuals: 3898.099233278053
# The sum of squared residuals: 0.5535691976205162
# The sum of squared residuals: 0.01501474561299931
# The sum of squared residuals: 0.015014742300073509
# The sum of squared residuals: 0.015014742300073094
# The sum of squared residuals: 3517.961061059566
# The sum of squared residuals: 0.006060174481329322
# The sum of squared residuals: 0.0002487462491133341
# The sum of squared residuals: 0.0002487462206431239
# The sum of squared residuals: 0.00024874622064326586
# The sum of squared residuals: 2658.4228229210157
# The sum of squared residuals: 0.744512589886804
# The sum of squared residuals: 0.0020729942096208162
# The sum of squared residuals: 0.0020729488623823854
# The sum of squared residuals: 0.00207294886238211
# The sum of squared residuals: 2215.21707626994
# The sum of squared residuals: 0.7461858555923039
# The sum of squared residuals: 0.04223718411243349
# The sum of squared residuals: 0.04223714938316432
# The sum of squared residuals: 0.042237149383166216
# The sum of squared residuals: 2583.339242068643
# The sum of squared residuals: 1.3799846470660215
# The sum of squared residuals: 0.00658386208643481
# The sum of squared residuals: 0.006583590833601972
# The sum of squared residuals: 0.006583590833601145
# The sum of squared residuals: 2077.570220047627
# The sum of squared residuals: 0.8203287080164338
# The sum of squared residuals: 0.03543716135823267
# The sum of squared residuals: 0.03543703786189845
# The sum of squared residuals: 0.03543703786189918
# The sum of squared residuals: 2632.761060814838
# The sum of squared residuals: 0.16638525859998232
# The sum of squared residuals: 0.12733609126511675
# The sum of squared residuals: 0.1273360908427686
# The sum of squared residuals: 0.12733609084276243
# The sum of squared residuals: 2750.3448758336267
# The sum of squared residuals: 0.1735649074955771
# The sum of squared residuals: 0.1472411507618998
# The sum of squared residuals: 0.1472411497375145
# The sum of squared residuals: 0.14724114973751423
# The sum of squared residuals: 3413.2633436539986
# The sum of squared residuals: 0.5882288674630278
# The sum of squared residuals: 0.14108672825109603
# The sum of squared residuals: 0.14108671213715876
# The sum of squared residuals: 0.141086712137155
# The sum of squared residuals: 3347.866958333686
# The sum of squared residuals: 0.160204382067474
# The sum of squared residuals: 0.05318817516342463
# The sum of squared residuals: 0.053188174807074676
# The sum of squared residuals: 0.05318817480707738
# The sum of squared residuals: 2489.9091546038135
# The sum of squared residuals: 0.03854137054450682
# The sum of squared residuals: 0.021645637686822605
# The sum of squared residuals: 0.02164563734617394
# The sum of squared residuals: 0.021645637346174945
# The sum of squared residuals: 2941.1546286542825
# The sum of squared residuals: 2.6850503305945512
# The sum of squared residuals: 0.0004698978597812898
# The sum of squared residuals: 0.0004672044196325371
# The sum of squared residuals: 0.0004672044196325638
# The sum of squared residuals: 2699.879284039906
# The sum of squared residuals: 0.4106375251848248
# The sum of squared residuals: 0.018902683347628083
# The sum of squared residuals: 0.018902681702276082
# The sum of squared residuals: 0.018902681702276658
# The sum of squared residuals: 2184.291230955336
# The sum of squared residuals: 0.11448763572683018
# The sum of squared residuals: 0.032400154627299664
# The sum of squared residuals: 0.03240015461305591
# The sum of squared residuals: 0.03240015461305886
# The sum of squared residuals: 3619.3554859062974
# The sum of squared residuals: 0.0609052913068507
# The sum of squared residuals: 0.038109119121517626
# The sum of squared residuals: 0.03810911908421101
# The sum of squared residuals: 0.03810911908421014
# The sum of squared residuals: 2612.707432677802
# The sum of squared residuals: 0.06730550473845584
# The sum of squared residuals: 0.036428254607610455
# The sum of squared residuals: 0.03642825442858488
# The sum of squared residuals: 0.036428254428583356
# The sum of squared residuals: 3997.108899269761
# The sum of squared residuals: 0.1250085158935248
# The sum of squared residuals: 0.10409400344932061
# The sum of squared residuals: 0.10409400331801916
# The sum of squared residuals: 0.10409400331802168
# The sum of squared residuals: 2690.180264792636
# The sum of squared residuals: 0.006155910843857041
# The sum of squared residuals: 0.0010447290803909776
# The sum of squared residuals: 0.0010447290793943835
# The sum of squared residuals: 0.0010447290793944109
# The sum of squared residuals: 2353.3466698887346
# The sum of squared residuals: 0.19622738224731254
# The sum of squared residuals: 0.028642495977151843
# The sum of squared residuals: 0.028642493265717994
# The sum of squared residuals: 0.028642493265718095
# The sum of squared residuals: 3266.400166004228
# The sum of squared residuals: 0.5065535850457473
# The sum of squared residuals: 0.010743485602215788
# The sum of squared residuals: 0.010743451938407008
# The sum of squared residuals: 0.010743451938405441
# The sum of squared residuals: 3035.768138045784
# The sum of squared residuals: 1.1990711540668275
# The sum of squared residuals: 0.004240187467049261
# The sum of squared residuals: 0.004240035263351786
# The sum of squared residuals: 0.004240035263351962
# The sum of squared residuals: 2679.2826759100035
# The sum of squared residuals: 0.1283532464362685
# The sum of squared residuals: 0.06108653263774731
# The sum of squared residuals: 0.0610865318923107
# The sum of squared residuals: 0.06108653189231394
# The sum of squared residuals: 2639.239028758605
# The sum of squared residuals: 0.4056064587692371
# The sum of squared residuals: 0.00010497354671281728
# The sum of squared residuals: 0.00010496474695832335
# The sum of squared residuals: 0.00010496474695841597
# The sum of squared residuals: 2904.277183272146
# The sum of squared residuals: 0.5507790984804071
# The sum of squared residuals: 0.1953498473702306
# The sum of squared residuals: 0.19534982550971372
# The sum of squared residuals: 0.19534982550971436
# The sum of squared residuals: 3415.4041551364217
# The sum of squared residuals: 0.13152060863842813
# The sum of squared residuals: 0.0319655745126508
# The sum of squared residuals: 0.03196557421439728
# The sum of squared residuals: 0.03196557421439903
# The sum of squared residuals: 3238.6772428542245
# The sum of squared residuals: 0.7267711923004044
# The sum of squared residuals: 0.04254746853997053
# The sum of squared residuals: 0.042547459393346115
# The sum of squared residuals: 0.04254745939334205
# The sum of squared residuals: 3091.647214937924
# The sum of squared residuals: 0.03047606320517282
# The sum of squared residuals: 0.0037575404229071717
# The sum of squared residuals: 0.0037575404205161343
# The sum of squared residuals: 0.0037575404205157092
# The sum of squared residuals: 2615.053392191469
# The sum of squared residuals: 0.4356956788456942
# The sum of squared residuals: 0.006134757501438126
# The sum of squared residuals: 0.006134753856265735
# The sum of squared residuals: 0.006134753856266423
# The sum of squared residuals: 1957.3206891653654
# The sum of squared residuals: 0.10952586167284045
# The sum of squared residuals: 0.03585633602946687
# The sum of squared residuals: 0.035856335954308885
# The sum of squared residuals: 0.03585633595431016
# The sum of squared residuals: 1866.7037417908027
# The sum of squared residuals: 0.6011972157353952
# The sum of squared residuals: 0.21208908057154024
# The sum of squared residuals: 0.21208904368384868
# The sum of squared residuals: 0.21208904368384554
# The sum of squared residuals: 2991.0385575394416
# The sum of squared residuals: 0.0950728623711392
# The sum of squared residuals: 0.00037454968886313196
# The sum of squared residuals: 0.00037452870690891547
# The sum of squared residuals: 0.00037452870690885264
# The sum of squared residuals: 2967.3005124089937
# The sum of squared residuals: 0.04796845830750691
# The sum of squared residuals: 0.032142509771908793
# The sum of squared residuals: 0.0321425097690405
# The sum of squared residuals: 0.03214250976904015
# The sum of squared residuals: 2740.3546934660976
# The sum of squared residuals: 0.0839746833965973
# The sum of squared residuals: 0.07637190710799313
# The sum of squared residuals: 0.0763719071008715
# The sum of squared residuals: 0.07637190710087388
# The sum of squared residuals: 1852.7524453182873
# The sum of squared residuals: 0.2530071294430549
# The sum of squared residuals: 2.9477261660344133e-06
# The sum of squared residuals: 2.942059753183045e-06
# The sum of squared residuals: 2.9420597531739075e-06
# The sum of squared residuals: 2477.1811411924136
# The sum of squared residuals: 0.2402483580492884
# The sum of squared residuals: 0.012667613317850978
# The sum of squared residuals: 0.012667611349237235
# The sum of squared residuals: 0.01266761134923644
# The sum of squared residuals: 3370.4614710437972
# The sum of squared residuals: 0.6182379848146159
# The sum of squared residuals: 0.0006902687887516995
# ...
# The sum of squared residuals: 0.0006518681364268105
# The sum of squared residuals: 0.0006354058233178395
# The sum of squared residuals: 0.0006354058232995003
# The sum of squared residuals: 17522.73082437166
# The sum of squared residuals: 3.592233645241327
# The sum of squared residuals: 0.02574317852972222
# The sum of squared residuals: 0.025676548452560538
# The sum of squared residuals: 0.025676548452532304
# The sum of squared residuals: 18476.86315353237
# The sum of squared residuals: 1.6778827871015538
# The sum of squared residuals: 0.06022427231865395
# The sum of squared residuals: 0.06018819668825129
# The sum of squared residuals: 0.060188196688223
# The sum of squared residuals: 20751.899713284743
# The sum of squared residuals: 1.1874064994558535
# The sum of squared residuals: 0.0712687276388157
# The sum of squared residuals: 0.07125047414096536
# The sum of squared residuals: 0.07125047414095843
# The sum of squared residuals: 20821.23590852347
# The sum of squared residuals: 4.718873218284628
# The sum of squared residuals: 0.022434515510249185
# The sum of squared residuals: 0.022335604904692656
# The sum of squared residuals: 0.022335604904634373
# The sum of squared residuals: 18870.319941736067
# The sum of squared residuals: 2.2007502790188105
# The sum of squared residuals: 0.01054467519614763
# The sum of squared residuals: 0.010516580919370962
# The sum of squared residuals: 0.0105165809193664
# The sum of squared residuals: 18473.02739084038
# The sum of squared residuals: 1.843037071438974
# The sum of squared residuals: 0.00019171114799637913
# The sum of squared residuals: 0.00017415805870280016
# The sum of squared residuals: 0.00017415805870078547
# The sum of squared residuals: 19223.27096720309
# The sum of squared residuals: 0.29476504688033595
# The sum of squared residuals: 0.06186919566602219
# The sum of squared residuals: 0.061864018017548164
# The sum of squared residuals: 0.061864018017545305
# The sum of squared residuals: 18682.725694628778
# The sum of squared residuals: 0.04931599805537973
# The sum of squared residuals: 0.032810352397542264
# The sum of squared residuals: 0.03281009789004989
# The sum of squared residuals: 0.03281009789005173
# The sum of squared residuals: 20295.36344760437
# The sum of squared residuals: 1.15928430799319
# The sum of squared residuals: 0.003291694914930197
# The sum of squared residuals: 0.0032718671746706394
# The sum of squared residuals: 0.0032718671746635244
# The sum of squared residuals: 19347.783889299575
# The sum of squared residuals: 2.449045188916137
# The sum of squared residuals: 0.04709341081967797
# The sum of squared residuals: 0.04706499879993635
# The sum of squared residuals: 0.047064998799931076
# The sum of squared residuals: 18502.81427296436
# The sum of squared residuals: 1.1829949438734442
# The sum of squared residuals: 0.08233851658697984
# The sum of squared residuals: 0.08229353531372646
# The sum of squared residuals: 0.08229353531364783
# The sum of squared residuals: 17451.669564192693
# The sum of squared residuals: 0.047850168060821985
# The sum of squared residuals: 0.00050841131187605
# The sum of squared residuals: 0.0005063132293949517
# The sum of squared residuals: 0.0005063132293906001
# The sum of squared residuals: 20210.926537391188
# The sum of squared residuals: 4.589857924968193
# The sum of squared residuals: 0.0020456451997051027
# The sum of squared residuals: 0.0018341473827605626
# The sum of squared residuals: 0.0018341473822888947
# The sum of squared residuals: 17432.04509857279
# The sum of squared residuals: 0.024035545881675963
# The sum of squared residuals: 0.008733869653682376
# The sum of squared residuals: 0.008733459550926113
# The sum of squared residuals: 0.008733459550927004
# The sum of squared residuals: 19530.331237825016
# The sum of squared residuals: 17.55210726493782
# The sum of squared residuals: 0.009841678880854965
# The sum of squared residuals: 0.009113529931873176
# The sum of squared residuals: 0.009113529930400197
# The sum of squared residuals: 19540.973700647362
# The sum of squared residuals: 0.07206727411183039
# The sum of squared residuals: 0.03526274518008883
# The sum of squared residuals: 0.03526160717958391
# The sum of squared residuals: 0.035261607179582155
# The sum of squared residuals: 20045.993406930145
# The sum of squared residuals: 8.58146263577462
# The sum of squared residuals: 0.000568756281148688
# The sum of squared residuals: 0.0002610830050503275
# The sum of squared residuals: 0.0002610830046196308
# The sum of squared residuals: 18380.55495407007
# The sum of squared residuals: 0.19999175235901448
# The sum of squared residuals: 0.0037570999274380013
# The sum of squared residuals: 0.003753192294644717
# The sum of squared residuals: 0.003753192294643024
# The sum of squared residuals: 18529.70197703494
# The sum of squared residuals: 7.906877798297749
# The sum of squared residuals: 0.0688146699652333
# The sum of squared residuals: 0.06856769167314676
# The sum of squared residuals: 0.06856769167283881
# The sum of squared residuals: 19705.85289634352
# The sum of squared residuals: 0.6445765634915868
# The sum of squared residuals: 0.036458580983649215
# The sum of squared residuals: 0.036445478516040256
# The sum of squared residuals: 0.03644547851604063
# The sum of squared residuals: 19614.19899399294
# The sum of squared residuals: 1.2979117796731845
# The sum of squared residuals: 0.020748540671819374
# The sum of squared residuals: 0.020715618619071813
# The sum of squared residuals: 0.02071561861904846
# The sum of squared residuals: 19494.60246565514
# The sum of squared residuals: 4.474261348266809
# The sum of squared residuals: 0.219378077327425
# The sum of squared residuals: 0.21925832762289832
# The sum of squared residuals: 0.21925832762273384
# The sum of squared residuals: 20262.30758069557
# The sum of squared residuals: 2.5603079812534095
# The sum of squared residuals: 0.35339282886351275
# The sum of squared residuals: 0.3533414878112981
# The sum of squared residuals: 0.35334148781122393
# The sum of squared residuals: 18427.78484014182
# The sum of squared residuals: 8.861080790501882
# The sum of squared residuals: 0.04013213627265659
# The sum of squared residuals: 0.03995527574321723
# The sum of squared residuals: 0.03995527574311773
# The sum of squared residuals: 19706.39351256723
# The sum of squared residuals: 10.548045186202534
# The sum of squared residuals: 0.3561295852263354
# The sum of squared residuals: 0.35588164622782303
# The sum of squared residuals: 0.3558816462273984
# The sum of squared residuals: 19633.874944218194
# The sum of squared residuals: 0.5262841570197043
# The sum of squared residuals: 0.022688009129779446
# The sum of squared residuals: 0.02267687128804804
# The sum of squared residuals: 0.022676871288040613
# The sum of squared residuals: 20421.267028181675
# The sum of squared residuals: 0.9219635279261192
# The sum of squared residuals: 0.0009057780190271284
# The sum of squared residuals: 0.0008933357409430277
# The sum of squared residuals: 0.0008933357409407121
# The sum of squared residuals: 17337.941980546184
# The sum of squared residuals: 7.598765335346798
# The sum of squared residuals: 0.0773254788785298
# The sum of squared residuals: 0.07723818054513655
# The sum of squared residuals: 0.07723818054510226
# The sum of squared residuals: 20073.154316276235
# The sum of squared residuals: 1.3346187323630578
# The sum of squared residuals: 0.011635107491638177
# The sum of squared residuals: 0.01160146245695274
# The sum of squared residuals: 0.0116014624569316
# The sum of squared residuals: 18798.1585805939
# The sum of squared residuals: 4.1687070834901165
# The sum of squared residuals: 0.03565299396647126
# The sum of squared residuals: 0.03559241610764535
# The sum of squared residuals: 0.0355924161076218
# The sum of squared residuals: 19231.39371819322
# The sum of squared residuals: 0.41046676958326356
# The sum of squared residuals: 0.16862829351148412
# The sum of squared residuals: 0.1686255754500788
# The sum of squared residuals: 0.16862557545007598
# The sum of squared residuals: 18754.39079974415
# The sum of squared residuals: 0.3666449985849836
# The sum of squared residuals: 0.00014290601257107785
# The sum of squared residuals: 0.0001363161591083589
# The sum of squared residuals: 0.00013631615910624924
# The sum of squared residuals: 17886.116958762268
# The sum of squared residuals: 4.450621959355127
# The sum of squared residuals: 0.06977586374445492
# The sum of squared residuals: 0.06964766117376724
# The sum of squared residuals: 0.06964766117362889
# The sum of squared residuals: 20985.958419173006
# The sum of squared residuals: 5.069551851942926
# The sum of squared residuals: 0.13886295023487205
# The sum of squared residuals: 0.13866650162150468
# The sum of squared residuals: 0.13866650162111804
# The sum of squared residuals: 20477.208323701572
# The sum of squared residuals: 1.930839166896572
# The sum of squared residuals: 0.030117441445791697
# The sum of squared residuals: 0.030052960876408227
# The sum of squared residuals: 0.030052960876330782
# The sum of squared residuals: 20414.86645507772
# The sum of squared residuals: 1.9080402179561755
# The sum of squared residuals: 0.01462355035866213
# The sum of squared residuals: 0.014557998598794879
# The sum of squared residuals: 0.014557998598709265
# The sum of squared residuals: 20139.26442812145
# The sum of squared residuals: 6.224058268633825
# The sum of squared residuals: 0.015183259855964103
# The sum of squared residuals: 0.014942833667148367
# The sum of squared residuals: 0.014942833666759968
# The sum of squared residuals: 19345.315956822393
# The sum of squared residuals: 0.14247772413957147
# The sum of squared residuals: 0.024238316781210984
# The sum of squared residuals: 0.02423452116650262
# The sum of squared residuals: 0.024234521166498386
# The sum of squared residuals: 17076.79259921005
# The sum of squared residuals: 1.860998292972561
# The sum of squared residuals: 0.008441622481348705
# The sum of squared residuals: 0.008408855923566631
# The sum of squared residuals: 0.00840885592355451
# The sum of squared residuals: 20714.9606223078
# The sum of squared residuals: 7.243630614325961
# The sum of squared residuals: 0.12828281880502077
# The sum of squared residuals: 0.12799686837862595
# The sum of squared residuals: 0.12799686837803453
# The sum of squared residuals: 18424.616118196565
# The sum of squared residuals: 3.4727838580246684
# The sum of squared residuals: 0.022866548622612448
# The sum of squared residuals: 0.02277234532056869
# The sum of squared residuals: 0.022772345320488524
# The sum of squared residuals: 15402.439766786876
# The sum of squared residuals: 0.8230105123348208
# The sum of squared residuals: 0.006238510480648861
# The sum of squared residuals: 0.00622790000968295
# The sum of squared residuals: 0.006227900009681469
# The sum of squared residuals: 20229.550305718294
# The sum of squared residuals: 3.5986678422285965
# The sum of squared residuals: 0.01776317840696583
# The sum of squared residuals: 0.01768786742562064
# The sum of squared residuals: 0.017687867425567858
# The sum of squared residuals: 17677.543221407184
# The sum of squared residuals: 1.2552025155927284
# The sum of squared residuals: 0.0002878999186176544
# The sum of squared residuals: 0.00026570274450283605
# The sum of squared residuals: 0.00026570274449467504
# The sum of squared residuals: 20601.514746401284
# The sum of squared residuals: 0.15479156730794155
# The sum of squared residuals: 0.002184524355708214
# The sum of squared residuals: 0.0021805329557737156
# The sum of squared residuals: 0.0021805329557695852
# The sum of squared residuals: 21930.768273122052
# The sum of squared residuals: 0.23884528961750878
# The sum of squared residuals: 0.00016678033168569822
# The sum of squared residuals: 0.0001557868981142147
# The sum of squared residuals: 0.0001557868980898582
# The sum of squared residuals: 21388.107909351682
# The sum of squared residuals: 0.8796404730784662
# The sum of squared residuals: 0.08869793817241965
# The sum of squared residuals: 0.08867827909919088
# The sum of squared residuals: 0.08867827909918105
# The sum of squared residuals: 19518.636925477458
# The sum of squared residuals: 5.815968316673782
# The sum of squared residuals: 0.03254550358563418
# The sum of squared residuals: 0.03243736116351138
# The sum of squared residuals: 0.0324373611634618
# The sum of squared residuals: 17706.75917878663
# The sum of squared residuals: 0.6236225524116565
# The sum of squared residuals: 0.10752739043051118
# The sum of squared residuals: 0.10751391105351948
# The sum of squared residuals: 0.10751391105349711
# The sum of squared residuals: 18695.60921211396
# The sum of squared residuals: 0.5291981618751409
# The sum of squared residuals: 0.03995541686053673
# The sum of squared residuals: 0.03994477590769725
# The sum of squared residuals: 0.03994477590769133
# The sum of squared residuals: 19434.750978956617
# The sum of squared residuals: 0.05519295507251078
# The sum of squared residuals: 0.02834540543395105
# The sum of squared residuals: 0.028344411283218955
# The sum of squared residuals: 0.028344411283217113
# The sum of squared residuals: 20534.299396116803
# The sum of squared residuals: 10.936657460828496
# The sum of squared residuals: 0.06897533716059678
# The sum of squared residuals: 0.06851381802412687
# The sum of squared residuals: 0.06851381802316318
# The sum of squared residuals: 19051.10883832582
# The sum of squared residuals: 0.48675554271481847
# The sum of squared residuals: 0.00018943313225508365
# The sum of squared residuals: 0.00017908615634034203
# The sum of squared residuals: 0.0001790861563352108
# The sum of squared residuals: 18301.097364686084
# The sum of squared residuals: 2.8549073679464123
# The sum of squared residuals: 0.0712821368252041
# The sum of squared residuals: 0.07115585124584345
# The sum of squared residuals: 0.07115585124555598
# The sum of squared residuals: 18039.169758107917
# The sum of squared residuals: 1.9138844964210795
# The sum of squared residuals: 0.09218613692185286
# The sum of squared residuals: 0.0921404033905544
# The sum of squared residuals: 0.09214040339052497
# The sum of squared residuals: 21006.367226653405
# The sum of squared residuals: 1.0841661957133841
# The sum of squared residuals: 0.016852741552307003
# The sum of squared residuals: 0.01682873246171337
# The sum of squared residuals: 0.016828732461702044
# The sum of squared residuals: 20515.9139263933
# The sum of squared residuals: 4.751839895744121
# The sum of squared residuals: 0.045726157492381396
# The sum of squared residuals: 0.04550869888623801
# The sum of squared residuals: 0.04550869888556398
# The sum of squared residuals: 23365.27928134577
# The sum of squared residuals: 2.151153419912687
# The sum of squared residuals: 0.08650310734153457
# The sum of squared residuals: 0.08643722677189394
# The sum of squared residuals: 0.08643722677181764
# The sum of squared residuals: 19240.209258523453
# The sum of squared residuals: 2.5580194273722143
# The sum of squared residuals: 0.0046981710178104
# The sum of squared residuals: 0.004620004951622361
# The sum of squared residuals: 0.00462000495154585
# The sum of squared residuals: 20208.488030042718
# The sum of squared residuals: 0.1338672492123898
# The sum of squared residuals: 0.060386631613376235
# The sum of squared residuals: 0.06038309574126546
# The sum of squared residuals: 0.06038309574126382
# The sum of squared residuals: 22751.184879492917
# The sum of squared residuals: 0.02426104142371851
# The sum of squared residuals: 0.0005998458307091314
# The sum of squared residuals: 0.0005984523232967372
# The sum of squared residuals: 0.0005984523232919743
# The sum of squared residuals: 20591.006719421897
# The sum of squared residuals: 2.6536674501157913
# The sum of squared residuals: 0.0036898402360056497
# The sum of squared residuals: 0.003550633412530311
# The sum of squared residuals: 0.00355063341207665
# The sum of squared residuals: 20236.57579758691
# The sum of squared residuals: 1.1871007805488998
# The sum of squared residuals: 0.005806461610589071
# The sum of squared residuals: 0.005751511507848059
# The sum of squared residuals: 0.0057515115077260886
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Plot refined points
ax2 = fig.add_subplot(122, projection='3d')
ax2.scatter(Uref[0], Uref[1], Uref[2], c='green', marker='.')
ax2.set_title('Refined 3D Points')
ax2.view_init(elev=0, azim=-90)

# Set axis equal for better scaling
equal_aspect_ratio(ax2)

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Task 2.7:
# Compute the camera positions for the data in `gauss_newton.mat` and plot them together with the estimated 3D points. Try to understand why the noise in the estimated points looks as it does.

# %%
# Create 3D plot
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Plot refined 3D points (Uref)
ax.scatter(Uref[0], Uref[1], Uref[2], c='blue', marker='.')

# Compute camera positions, option 2
num_cams = len(Ps)
c = np.zeros((4, num_cams))
v = np.zeros((3, num_cams))

# Your code here
for i in range(num_cams):
    P = Ps[i]
    _, _, temp_c = np.linalg.svd(P)
    c[:, i] = temp_c[-1] / temp_c[-1][3]

    v[:, i] = P[2, :3]

# Plot camera centers and viewing directions
ax.quiver(c[0, :], c[1, :], c[2, :],
        v[0, :], v[1, :], v[2, :],
        color='r', linewidth=1.5)

# Set axis equal for better scaling
equal_aspect_ratio(ax)

# Show plot
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
